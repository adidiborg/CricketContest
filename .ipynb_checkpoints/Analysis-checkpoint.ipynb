# %%
import numpy as np
import pandas as pd
from statistics import mean

# %%
matches = pd.read_csv("dataset/all_matches.csv",low_memory=False)

# %%
matches = pd.read_csv("all_matches_under6.csv",low_memory=False)
matches = matches.loc[(matches['venue'] == "Arun Jaitley Stadium" ) & (matches['striker'] == "JM Bairstow" ) ]
matches
# Out:
#        Unnamed: 0  match_id                 venue  innings  ball  \
# 48844       48844   1175371  Arun Jaitley Stadium        2   0.5
# 48845       48845   1175371  Arun Jaitley Stadium        2   0.6
# 48846       48846   1175371  Arun Jaitley Stadium        2   1.1
# 48847       48847   1175371  Arun Jaitley Stadium        2   1.2
# 48848       48848   1175371  Arun Jaitley Stadium        2   1.3
# 48849       48849   1175371  Arun Jaitley Stadium        2   1.4
# 48850       48850   1175371  Arun Jaitley Stadium        2   1.5
# 48851       48851   1175371  Arun Jaitley Stadium        2   1.6
# 48852       48852   1175371  Arun Jaitley Stadium        2   2.1
# 48853       48853   1175371  Arun Jaitley Stadium        2   2.2
# 48854       48854   1175371  Arun Jaitley Stadium        2   2.3
# 48858       48858   1175371  Arun Jaitley Stadium        2   3.1
# 48859       48859   1175371  Arun Jaitley Stadium        2   3.2
# ...
