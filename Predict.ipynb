# %%
import pandas as pd
import numpy as np

# %%
matches = pd.read_csv("dataset/all_matches.csv")

# %%
filter_1 = matches.loc[matches['venue'] == "MA Chidambaram Stadium"]
filter_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2130 entries, 150460 to 178319
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                2130 non-null   int64
#  1   season                  2130 non-null   object
#  2   start_date              2130 non-null   object
#  3   venue                   2130 non-null   object
#  4   innings                 2130 non-null   int64
#  5   ball                    2130 non-null   float64
#  6   batting_team            2130 non-null   object
#  7   bowling_team            2130 non-null   object
#  8   striker                 2130 non-null   object
#  9   non_striker             2130 non-null   object
#  10  bowler                  2130 non-null   object
#  11  runs_off_bat            2130 non-null   int64
#  12  extras                  2130 non-null   int64
#  13  wides                   50 non-null     float64
# ...

# %%
filter_2 = filter_1.loc[filter_1['batting_team'] == "Mumbai Indians"]
filter_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 236 entries, 175171 to 178319
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                236 non-null    int64
#  1   season                  236 non-null    object
#  2   start_date              236 non-null    object
#  3   venue                   236 non-null    object
#  4   innings                 236 non-null    int64
#  5   ball                    236 non-null    float64
#  6   batting_team            236 non-null    object
#  7   bowling_team            236 non-null    object
#  8   striker                 236 non-null    object
#  9   non_striker             236 non-null    object
#  10  bowler                  236 non-null    object
#  11  runs_off_bat            236 non-null    int64
#  12  extras                  236 non-null    int64
#  13  wides                   5 non-null      float64
# ...

# %%
filter_3 = filter_2.loc[filter_2['ball'] < 6]
filter_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 74 entries, 175171 to 178243
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   match_id                74 non-null     int64
#  1   season                  74 non-null     object
#  2   start_date              74 non-null     object
#  3   venue                   74 non-null     object
#  4   innings                 74 non-null     int64
#  5   ball                    74 non-null     float64
#  6   batting_team            74 non-null     object
#  7   bowling_team            74 non-null     object
#  8   striker                 74 non-null     object
#  9   non_striker             74 non-null     object
#  10  bowler                  74 non-null     object
#  11  runs_off_bat            74 non-null     int64
#  12  extras                  74 non-null     int64
#  13  wides                   2 non-null      float64
# ...

# %%
filter_3
# Out:
#         match_id season  start_date                   venue  innings  ball  \
# 175171   1178419   2019  2019-04-26  MA Chidambaram Stadium        1   0.1
# 175172   1178419   2019  2019-04-26  MA Chidambaram Stadium        1   0.2
# 175173   1178419   2019  2019-04-26  MA Chidambaram Stadium        1   0.3
# 175174   1178419   2019  2019-04-26  MA Chidambaram Stadium        1   0.4
# 175175   1178419   2019  2019-04-26  MA Chidambaram Stadium        1   0.5
# ...          ...    ...         ...                     ...      ...   ...
# 178239   1181764   2019  2019-05-07  MA Chidambaram Stadium        2   5.2
# 178240   1181764   2019  2019-05-07  MA Chidambaram Stadium        2   5.3
# 178241   1181764   2019  2019-05-07  MA Chidambaram Stadium        2   5.4
# 178242   1181764   2019  2019-05-07  MA Chidambaram Stadium        2   5.5
# 178243   1181764   2019  2019-05-07  MA Chidambaram Stadium        2   5.6
#
# ...
